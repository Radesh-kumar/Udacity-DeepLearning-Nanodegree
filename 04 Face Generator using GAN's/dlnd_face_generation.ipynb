# %% [markdown]
# # Face Generation
#
# In this project, you'll define and train a DCGAN on a dataset of faces. Your goal is to get a generator network to generate *new* images of faces that look as realistic as possible!
#
# The project will be broken down into a series of tasks from **loading in data to defining and training adversarial networks**. At the end of the notebook, you'll be able to visualize the results of your trained Generator to see how it performs; your generated samples should look like fairly realistic faces with small amounts of noise.
#
# ### Get the Data
#
# You'll be using the [CelebFaces Attributes Dataset (CelebA)](http://mmlab.ie.cuhk.edu.hk/projects/CelebA.html) to train your adversarial networks.
#
# This dataset is more complex than the number datasets (like MNIST or SVHN) you've been working with, and so, you should prepare to define deeper networks and train them for a longer time to get good results. It is suggested that you utilize a GPU for training.
#
# ### Pre-processed Data
#
# Since the project's main focus is on building the GANs, we've done *some* of the pre-processing for you. Each of the CelebA images has been cropped to remove parts of the image that don't include a face, then resized down to 64x64x3 NumPy images. Some sample data is show below.
#
# <img src='assets/processed_face_data.png' width=60% />
#
# > If you are working locally, you can download this data [by clicking here](https://s3.amazonaws.com/video.udacity-data.com/topher/2018/November/5be7eb6f_processed-celeba-small/processed-celeba-small.zip)
#
# This is a zip file that you'll need to extract in the home directory of this notebook for further loading and processing. After extracting the data, you should be left with a directory of data `processed_celeba_small/`

# %%
# can comment out after executing
#!unzip processed_celeba_small.zip

# %%
data_dir = 'processed_celeba_small/'

"""
DON'T MODIFY ANYTHING IN THIS CELL
"""
import pickle as pkl
import matplotlib.pyplot as plt
import numpy as np
import problem_unittests as tests
#import helper

# %matplotlib inline

# %% [markdown]
# ## Visualize the CelebA Data
#
# The [CelebA](http://mmlab.ie.cuhk.edu.hk/projects/CelebA.html) dataset contains over 200,000 celebrity images with annotations. Since you're going to be generating faces, you won't need the annotations, you'll only need the images. Note that these are color images with [3 color channels (RGB)](https://en.wikipedia.org/wiki/Channel_(digital_image)#RGB_Images) each.
#
# ### Pre-process and Load the Data
#
# Since the project's main focus is on building the GANs, we've done *some* of the pre-processing for you. Each of the CelebA images has been cropped to remove parts of the image that don't include a face, then resized down to 64x64x3 NumPy images. This *pre-processed* dataset is a smaller subset of the very large CelebA data.
#
# > There are a few other steps that you'll need to **transform** this data and create a **DataLoader**.
#
# #### Exercise: Complete the following `get_dataloader` function, such that it satisfies these requirements:
#
# * Your images should be square, Tensor images of size `image_size x image_size` in the x and y dimension.
# * Your function should return a DataLoader that shuffles and batches these Tensor images.
#
# #### ImageFolder
#
# To create a dataset given a directory of images, it's recommended that you use PyTorch's [ImageFolder](https://pytorch.org/docs/stable/torchvision/datasets.html#imagefolder) wrapper, with a root directory `processed_celeba_small/` and data transformation passed in.

# %%
# necessary imports
import torch
from torchvision import datasets
from torchvision import transforms

# %%
def get_dataloader(batch_size, image_size, data_dir='processed_celeba_small/'):
    """
    Batch the neural network data using DataLoader
    :param batch_size: The size of each batch; the number of images in a batch
    :param img_size: The square size of the image data (x, y)
    :param data_dir: Directory where image data is located
    :return: DataLoader with batched data
    """
    
    # TODO: Implement function and return a dataloader
    transform = transforms.Compose([transforms.Resize(image_size), transforms.CenterCrop(image_size), transforms.ToTensor()])
    dataset = datasets.ImageFolder(data_dir, transform)
    data_loader = torch.utils.data.DataLoader(dataset, batch_size=batch_size, shuffle=True, num_workers = 4)
    return data_loader

# %% [markdown]
# ## Create a DataLoader
#
# #### Exercise: Create a DataLoader `celeba_train_loader` with appropriate hyperparameters.
#
# Call the above function and create a dataloader to view images.
# * You can decide on any reasonable `batch_size` parameter
# * Your `image_size` **must be** `32`. Resizing the data to a smaller size will make for faster training, while still creating convincing images of faces!

# %%
# Define function hyperparameters
batch_size = 32
img_size = 32
"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
# Call your function and get a dataloader
celeba_train_loader = get_dataloader(batch_size, img_size)

# %% [markdown]
# Next, you can view some images! You should seen square images of somewhat-centered faces.
#
# Note: You'll need to convert the Tensor images into a NumPy type and transpose the dimensions to correctly display an image, suggested `imshow` code is below, but it may not be perfect.

# %%
# helper display function
def imshow(img):
    npimg = img.numpy()
    plt.imshow(np.transpose(npimg, (1, 2, 0)))

"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
# obtain one batch of training images
dataiter = iter(celeba_train_loader)
images, _ = dataiter.next() # _ for no labels

# plot the images in the batch, along with the corresponding labels
fig = plt.figure(figsize=(20, 4))
plot_size=20
for idx in np.arange(plot_size):
    ax = fig.add_subplot(2, plot_size/2, idx+1, xticks=[], yticks=[])
    imshow(images[idx])

# %% [markdown]
# #### Exercise: Pre-process your image data and scale it to a pixel range of -1 to 1
#
# You need to do a bit of pre-processing; you know that the output of a `tanh` activated generator will contain pixel values in a range from -1 to 1, and so, we need to rescale our training images to a range of -1 to 1. (Right now, they are in a range from 0-1.)

# %%
# TODO: Complete the scale function
def scale(x, feature_range=(-1, 1)):
    ''' Scale takes in an image x and returns that image, scaled
       with a feature_range of pixel values from -1 to 1. 
       This function assumes that the input x is already scaled from 0-1.'''
    # assume x is scaled to (0, 1)
    # scale to feature_range and return scaled x
    
    min, max = feature_range
    x = x * (max - min) + min
    return x

# %%
"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
# check scaled range
# should be close to -1 to 1
img = images[0]
scaled_img = scale(img)

print('Min: ', scaled_img.min())
print('Max: ', scaled_img.max())
# Out:
# Min:  tensor(-0.9922)
# Max:  tensor(0.6941)

# %% [markdown]
# ---
# # Define the Model
#
# A GAN is comprised of two adversarial networks, a discriminator and a generator.
#
# ## Discriminator
#
# Your first task will be to define the discriminator. This is a convolutional classifier like you've built before, only without any maxpooling layers. To deal with this complex data, it's suggested you use a deep network with **normalization**. You are also allowed to create any helper functions that may be useful.
#
# #### Exercise: Complete the Discriminator class
# * The inputs to the discriminator are 32x32x3 tensor images
# * The output should be a single value that will indicate whether a given image is real or fake

# %%
import torch.nn as nn
import torch.nn.functional as F

# %%
class Discriminator(nn.Module):

    def __init__(self, conv_dim):
        """
        Initialize the Discriminator Module
        :param conv_dim: The depth of the first convolutional layer
        """
        super(Discriminator, self).__init__()

        # complete init function

        self.conv_dim = conv_dim
        
        self.conv_1 = nn.Conv2d(3, conv_dim, kernel_size=4, stride=2, padding=1, bias=False)  
        self.conv_2 = nn.Conv2d(conv_dim, conv_dim*2, kernel_size=4, stride=2, padding=1, bias=False)           
        self.conv_3 = nn.Conv2d(conv_dim*2, conv_dim*4,  kernel_size=4, stride=2, padding=1, bias=False)
        self.conv_4 = nn.Conv2d(conv_dim*4, conv_dim*8,  kernel_size=4, stride=2, padding=1, bias=False)
        self.conv_5 = nn.Conv2d(conv_dim*8, conv_dim*16,  kernel_size=4, stride=2, padding=1, bias=False)

        #self.batch_norm_1 = nn.BatchNorm2d(conv_dim)
        self.batch_norm_2 = nn.BatchNorm2d(conv_dim * 2)
        self.batch_norm_3 = nn.BatchNorm2d(conv_dim * 4)
        self.batch_norm_4 = nn.BatchNorm2d(conv_dim * 8)
        
        self.fc = nn.Linear(conv_dim*4*2*2, 1)
        
    def forward(self, x):
        """
        Forward propagation of the neural network
        :param x: The input to the neural network     
        :return: Discriminator logits; the output of the neural network
        """
        # define feedforward behavior
        
        output = F.leaky_relu((self.conv_1(x)), 0.2)
        output = F.leaky_relu(self.batch_norm_2(self.conv_2(output)), 0.2)
        output = F.leaky_relu(self.batch_norm_3(self.conv_3(output)), 0.2)
        output = F.leaky_relu(self.batch_norm_4(self.conv_4(output)), 0.2)
        output = self.conv_5(output)
        output = output.view(-1, self.conv_dim*4*2*2)
        output = F.sigmoid(self.fc(output))
        return output

"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
tests.test_discriminator(Discriminator)
# Out:
# Tests Passed

# %% [markdown]
# ## Generator
#
# The generator should upsample an input and generate a *new* image of the same size as our training data `32x32x3`. This should be mostly transpose convolutional layers with normalization applied to the outputs.
#
# #### Exercise: Complete the Generator class
# * The inputs to the generator are vectors of some length `z_size`
# * The output should be a image of shape `32x32x3`

# %%
class Generator(nn.Module):
    
    def __init__(self, z_size, conv_dim):
        """
        Initialize the Generator Module
        :param z_size: The length of the input latent vector, z
        :param conv_dim: The depth of the inputs to the *last* transpose convolutional layer
        """
        super(Generator, self).__init__()

        # complete init function
        self.conv_dim = conv_dim
        self.fc = nn.Linear(z_size, conv_dim*4*4*4*2)
        
        self.de_conv_1 = nn.ConvTranspose2d(conv_dim*4*2, conv_dim*4, kernel_size=4, stride=2, padding=1,)  
        self.de_conv_2 = nn.ConvTranspose2d(conv_dim*4, conv_dim*2, kernel_size=4, stride=2, padding=1,)           
        self.de_conv_3 = nn.ConvTranspose2d(conv_dim*2, 3,  kernel_size=4, stride=2, padding=1,)


    def forward(self, x):
        """
        Forward propagation of the neural network
        :param x: The input to the neural network     
        :return: A 32x32x3 Tensor image as output
        """

        output = self.fc(x)
        #print(output.size())
        output = output.view(-1, self.conv_dim*4*2, 4, 4)
        #print(output.size())
        
        output = F.relu(self.de_conv_1(output))
        #print(output.size())
        output = F.relu(self.de_conv_2(output))
        #print(output.size())
        output = F.tanh(self.de_conv_3(output))
        #print(output.size())
        return output

"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
tests.test_generator(Generator)
# Out:
# Tests Passed

# %% [markdown]
# ## Initialize the weights of your networks
#
# To help your models converge, you should initialize the weights of the convolutional and linear layers in your model. From reading the [original DCGAN paper](https://arxiv.org/pdf/1511.06434.pdf), they say:
# > All weights were initialized from a zero-centered Normal distribution with standard deviation 0.02.
#
# So, your next task will be to define a weight initialization function that does just this!
#
# You can refer back to the lesson on weight initialization or even consult existing model code, such as that from [the `networks.py` file in CycleGAN Github repository](https://github.com/junyanz/pytorch-CycleGAN-and-pix2pix/blob/master/models/networks.py) to help you complete this function.
#
# #### Exercise: Complete the weight initialization function
#
# * This should initialize only **convolutional** and **linear** layers
# * Initialize the weights to a normal distribution, centered around 0, with a standard deviation of 0.02.
# * The bias terms, if they exist, may be left alone or set to 0.

# %%
def weights_init_normal(m):
    """
    Applies initial weights to certain layers in a model .
    The weights are taken from a normal distribution 
    with mean = 0, std dev = 0.02.
    :param m: A module or layer in a network    
    """
    # classname will be something like:
    # `Conv`, `BatchNorm2d`, `Linear`, etc.
    classname = m.__class__.__name__
    
    # TODO: Apply initial weights to convolutional and linear layers
    if classname.find('Linear') != -1 or classname.find('Convo2d') != -1:
        torch.nn.init.normal_(m.weight.data, 0.0, 0.02)
        m.bias.data.fill_(0)

# %% [markdown]
# ## Build complete network
#
# Define your models' hyperparameters and instantiate the discriminator and generator from the classes defined above. Make sure you've passed in the correct input arguments.

# %%
"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
def build_network(d_conv_dim, g_conv_dim, z_size):
    # define discriminator and generator
    D = Discriminator(d_conv_dim)
    G = Generator(z_size=z_size, conv_dim=g_conv_dim)

    # initialize model weights
    D.apply(weights_init_normal)
    G.apply(weights_init_normal)

    print(D)
    print()
    print(G)
    
    return D, G

# %% [markdown]
# #### Exercise: Define model hyperparameters

# %%
# Define model hyperparams
d_conv_dim = 64
g_conv_dim = 64
z_size = 150

"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
D, G = build_network(d_conv_dim, g_conv_dim, z_size)
# Out:
# Discriminator(
#   (conv_1): Conv2d(3, 64, kernel_size=(4, 4), stride=(2, 2), padding=(1, 1), bias=False)
#   (conv_2): Conv2d(64, 128, kernel_size=(4, 4), stride=(2, 2), padding=(1, 1), bias=False)
#   (conv_3): Conv2d(128, 256, kernel_size=(4, 4), stride=(2, 2), padding=(1, 1), bias=False)
#   (conv_4): Conv2d(256, 512, kernel_size=(4, 4), stride=(2, 2), padding=(1, 1), bias=False)
#   (conv_5): Conv2d(512, 1024, kernel_size=(4, 4), stride=(2, 2), padding=(1, 1), bias=False)
#   (batch_norm_2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (batch_norm_3): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (batch_norm_4): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (fc): Linear(in_features=1024, out_features=1, bias=True)
# )
#
# Generator(
#   (fc): Linear(in_features=150, out_features=8192, bias=True)
#   (de_conv_1): ConvTranspose2d(512, 256, kernel_size=(4, 4), stride=(2, 2), padding=(1, 1))
#   (de_conv_2): ConvTranspose2d(256, 128, kernel_size=(4, 4), stride=(2, 2), padding=(1, 1))
#   (de_conv_3): ConvTranspose2d(128, 3, kernel_size=(4, 4), stride=(2, 2), padding=(1, 1))
# )

# %% [markdown]
# ### Training on GPU
#
# Check if you can train on GPU. Here, we'll set this as a boolean variable `train_on_gpu`. Later, you'll be responsible for making sure that
# >* Models,
# * Model inputs, and
# * Loss function arguments
#
# Are moved to GPU, where appropriate.

# %%
"""
DON'T MODIFY ANYTHING IN THIS CELL
"""
import torch

# Check for a GPU
train_on_gpu = torch.cuda.is_available()
if not train_on_gpu:
    print('No GPU found. Please use a GPU to train your neural network.')
else:
    print('Training on GPU!')
# Out:
# Training on GPU!

# %% [markdown]
# ---
# ## Discriminator and Generator Losses
#
# Now we need to calculate the losses for both types of adversarial networks.
#
# ### Discriminator Losses
#
# > * For the discriminator, the total loss is the sum of the losses for real and fake images, `d_loss = d_real_loss + d_fake_loss`.
# * Remember that we want the discriminator to output 1 for real images and 0 for fake images, so we need to set up the losses to reflect that.
#
#
# ### Generator Loss
#
# The generator loss will look similar only with flipped labels. The generator's goal is to get the discriminator to *think* its generated images are *real*.
#
# #### Exercise: Complete real and fake loss functions
#
# **You may choose to use either cross entropy or a least squares error loss to complete the following `real_loss` and `fake_loss` functions.**

# %%
def real_loss(D_out, smooth=False):
    '''Calculates how close discriminator outputs are to being real.
       param, D_out: discriminator logits
       return: real loss'''

    batch_size = D_out.size(0)
    if smooth:
        labels = torch.ones(batch_size)*0.9
    else:
        labels = torch.ones(batch_size)
    if train_on_gpu:
        labels = labels.cuda()
    criterion = nn.BCELoss()
    loss = criterion(D_out.squeeze(), labels)
    return loss

def fake_loss(D_out):
    '''Calculates how close discriminator outputs are to being fake.
       param, D_out: discriminator logits
       return: fake loss'''
    batch_size = D_out.size(0)
    labels = torch.zeros(batch_size)
    if train_on_gpu:
        labels = labels.cuda()
    criterion = nn.BCELoss()
    loss = criterion(D_out.squeeze(), labels)
    return loss

# %% [markdown]
# ## Optimizers
#
# #### Exercise: Define optimizers for your Discriminator (D) and Generator (G)
#
# Define optimizers for your models with appropriate hyperparameters.

# %%
import torch.optim as optim

lr = 0.0001
beta1 = 0.333
beta2 = 0.999 
# Create optimizers for the discriminator D and generator G
d_optimizer = optim.Adam(D.parameters(), lr, betas=(beta1, beta2))
g_optimizer = optim.Adam(G.parameters(), lr, betas=(beta1, beta2))

# %% [markdown]
# ---
# ## Training
#
# Training will involve alternating between training the discriminator and the generator. You'll use your functions `real_loss` and `fake_loss` to help you calculate the discriminator losses.
#
# * You should train the discriminator by alternating on real and fake images
# * Then the generator, which tries to trick the discriminator and should have an opposing loss function
#
#
# #### Saving Samples
#
# You've been given some code to print out some loss statistics and save some generated "fake" samples.

# %% [markdown]
# #### Exercise: Complete the training function
#
# Keep in mind that, if you've moved your models to GPU, you'll also have to move any model inputs to GPU.

# %%
def train(D, G, n_epochs, print_every=50):
    '''Trains adversarial networks for some number of epochs
       param, D: the discriminator network
       param, G: the generator network
       param, n_epochs: number of epochs to train for
       param, print_every: when to print and record the models' losses
       return: D and G losses'''
    
    # move models to GPU
    if train_on_gpu:
        D.cuda()
        G.cuda()

    # keep track of loss and generated, "fake" samples
    samples = []
    losses = []

    # Get some fixed data for sampling. These are images that are held
    # constant throughout training, and allow us to inspect the model's performance
    sample_size=16
    fixed_z = np.random.uniform(-1, 1, size=(sample_size, z_size))
    fixed_z = torch.from_numpy(fixed_z).float()
    # move z to GPU if available
    if train_on_gpu:
        fixed_z = fixed_z.cuda()

    # epoch training loop
    for epoch in range(n_epochs):

        # batch training loop
        for batch_i, (real_images, _) in enumerate(celeba_train_loader):

            batch_size = real_images.size(0)
            real_images = scale(real_images)

            # ===============================================
            #         YOUR CODE HERE: TRAIN THE NETWORKS
            # ===============================================
            
            # ---------TRAIN THE DISCRIMINATOR ----------------
            d_optimizer.zero_grad()
            
            if train_on_gpu:
                real_images = real_images.cuda()
            D_real = D(real_images)
            d_real_loss = real_loss(D_real)

            # Generating fake images
            z = np.random.uniform(-1, 1, size=(batch_size, z_size))
            z = torch.from_numpy(z).float() 
            if train_on_gpu:
                z = z.cuda()
            fake_images = G(z)
            D_fake = D(fake_images)
            d_fake_loss = fake_loss(D_fake)
            
            # Calculate loss and Back Propagate
            d_loss = d_real_loss + d_fake_loss
            d_loss.backward()
            d_optimizer.step()
            
            # ---------TRAIN THE GENERATOR ----------------
            
            g_optimizer.zero_grad()
            # Generating fake images
            z = np.random.uniform(-1, 1, size=(batch_size, z_size))
            z = torch.from_numpy(z).float()
            if train_on_gpu:
                z = z.cuda()
            fake_images = G(z)
            
            # Calculate loss and Back Propagate 
            D_fake = D(fake_images)
            g_loss = real_loss(D_fake)
            g_loss.backward()
            g_optimizer.step()
            # ===============================================
            #              END OF YOUR CODE
            # ===============================================

            # Print some loss stats
            if batch_i % print_every == 0:
                # append discriminator loss and generator loss
                losses.append((d_loss.item(), g_loss.item()))
                # print discriminator and generator loss
                print('Epoch [{:5d}/{:5d}] | d_loss: {:6.4f} | g_loss: {:6.4f}'.format(
                        epoch+1, n_epochs, d_loss.item(), g_loss.item()))


        ## AFTER EACH EPOCH##    
        # this code assumes your generator is named G, feel free to change the name
        # generate and save sample, fake images
        G.eval() # for generating samples
        samples_z = G(fixed_z)
        samples.append(samples_z)
        G.train() # back to training mode

    # Save training generator samples
    with open('train_samples.pkl', 'wb') as f:
        pkl.dump(samples, f)
    
    # finally return losses
    return losses

# %% [markdown]
# Set your number of training epochs and train your GAN!

# %%
import workspace_utils
from workspace_utils import active_session
# set number of epochs 
n_epochs = 10

"""
DON'T MODIFY ANYTHING IN THIS CELL
"""
# call training function


with active_session():
    losses = train(D, G, n_epochs=n_epochs)
# Out:
# Epoch [    1/   10] | d_loss: 1.4091 | g_loss: 1.3024
# Epoch [    1/   10] | d_loss: 1.3478 | g_loss: 5.5891
# Epoch [    1/   10] | d_loss: 0.2543 | g_loss: 6.4420
# Epoch [    1/   10] | d_loss: 0.0937 | g_loss: 3.7176
# Epoch [    1/   10] | d_loss: 0.3914 | g_loss: 4.0774
# Epoch [    1/   10] | d_loss: 0.5389 | g_loss: 3.6092
# Epoch [    1/   10] | d_loss: 0.8975 | g_loss: 0.8477
# Epoch [    1/   10] | d_loss: 0.8903 | g_loss: 3.7416
# Epoch [    1/   10] | d_loss: 0.5776 | g_loss: 2.7218
# Epoch [    1/   10] | d_loss: 0.4504 | g_loss: 2.1940
# Epoch [    1/   10] | d_loss: 1.5128 | g_loss: 0.6443
# Epoch [    1/   10] | d_loss: 0.6178 | g_loss: 0.8720
# Epoch [    1/   10] | d_loss: 0.4505 | g_loss: 2.6450
# Epoch [    1/   10] | d_loss: 1.2657 | g_loss: 0.7647
# Epoch [    1/   10] | d_loss: 1.0011 | g_loss: 3.9431
# Epoch [    1/   10] | d_loss: 1.4641 | g_loss: 1.5033
# Epoch [    1/   10] | d_loss: 0.6300 | g_loss: 1.8855
# Epoch [    1/   10] | d_loss: 0.8664 | g_loss: 3.8690
# Epoch [    1/   10] | d_loss: 0.9499 | g_loss: 3.3822
# Epoch [    1/   10] | d_loss: 0.4204 | g_loss: 1.2922
# Epoch [    1/   10] | d_loss: 0.6215 | g_loss: 2.6565
# Epoch [    1/   10] | d_loss: 0.7501 | g_loss: 1.4302
# Epoch [    1/   10] | d_loss: 0.5694 | g_loss: 1.6965
# Epoch [    1/   10] | d_loss: 0.4430 | g_loss: 2.7540
# Epoch [    1/   10] | d_loss: 0.5365 | g_loss: 1.5466
# Epoch [    1/   10] | d_loss: 0.7450 | g_loss: 3.3219
# Epoch [    1/   10] | d_loss: 0.8159 | g_loss: 0.9480
# Epoch [    1/   10] | d_loss: 0.6541 | g_loss: 2.4511
# Epoch [    1/   10] | d_loss: 0.7186 | g_loss: 1.6852
# Epoch [    1/   10] | d_loss: 0.8930 | g_loss: 1.0398
# Epoch [    1/   10] | d_loss: 1.1088 | g_loss: 3.2377
# Epoch [    1/   10] | d_loss: 0.6809 | g_loss: 3.8535
# Epoch [    1/   10] | d_loss: 0.3691 | g_loss: 2.1159
# Epoch [    1/   10] | d_loss: 0.4112 | g_loss: 3.0865
# Epoch [    1/   10] | d_loss: 0.3905 | g_loss: 2.1605
# Epoch [    1/   10] | d_loss: 0.5774 | g_loss: 1.6635
# Epoch [    1/   10] | d_loss: 1.2301 | g_loss: 3.4542
# Epoch [    1/   10] | d_loss: 0.5218 | g_loss: 1.3724
# Epoch [    1/   10] | d_loss: 0.8470 | g_loss: 2.2509
# Epoch [    1/   10] | d_loss: 0.6375 | g_loss: 1.7933
# Epoch [    1/   10] | d_loss: 0.6457 | g_loss: 2.5048
# Epoch [    1/   10] | d_loss: 0.2981 | g_loss: 2.3622
# Epoch [    1/   10] | d_loss: 1.2414 | g_loss: 0.9495
# Epoch [    1/   10] | d_loss: 0.3916 | g_loss: 1.7485
# Epoch [    1/   10] | d_loss: 0.7824 | g_loss: 0.3359
# Epoch [    1/   10] | d_loss: 0.5700 | g_loss: 2.9122
# Epoch [    1/   10] | d_loss: 0.9019 | g_loss: 1.5962
# Epoch [    1/   10] | d_loss: 0.5716 | g_loss: 0.4847
# Epoch [    1/   10] | d_loss: 0.4360 | g_loss: 2.2917
# Epoch [    1/   10] | d_loss: 0.6358 | g_loss: 2.6821
# Epoch [    1/   10] | d_loss: 0.8141 | g_loss: 1.4425
# Epoch [    1/   10] | d_loss: 0.8252 | g_loss: 2.8740
# Epoch [    1/   10] | d_loss: 0.3514 | g_loss: 1.8458
# Epoch [    1/   10] | d_loss: 2.6049 | g_loss: 4.3381
# Epoch [    1/   10] | d_loss: 0.6542 | g_loss: 2.2488
# Epoch [    1/   10] | d_loss: 0.5954 | g_loss: 1.4629
# Epoch [    1/   10] | d_loss: 1.1954 | g_loss: 2.9546
# Epoch [    2/   10] | d_loss: 0.6378 | g_loss: 1.4785
# Epoch [    2/   10] | d_loss: 0.7340 | g_loss: 2.6751
# Epoch [    2/   10] | d_loss: 0.5892 | g_loss: 1.8211
# Epoch [    2/   10] | d_loss: 0.7492 | g_loss: 2.7006
# Epoch [    2/   10] | d_loss: 0.4445 | g_loss: 1.0406
# Epoch [    2/   10] | d_loss: 1.0876 | g_loss: 1.1749
# Epoch [    2/   10] | d_loss: 0.3444 | g_loss: 2.8097
# Epoch [    2/   10] | d_loss: 1.1295 | g_loss: 3.1644
# Epoch [    2/   10] | d_loss: 0.4587 | g_loss: 2.7856
# Epoch [    2/   10] | d_loss: 0.8537 | g_loss: 3.6291
# Epoch [    2/   10] | d_loss: 0.4545 | g_loss: 2.9023
# Epoch [    2/   10] | d_loss: 0.5032 | g_loss: 2.5013
# Epoch [    2/   10] | d_loss: 1.7265 | g_loss: 4.9067
# Epoch [    2/   10] | d_loss: 0.8037 | g_loss: 0.8241
# Epoch [    2/   10] | d_loss: 0.8425 | g_loss: 3.0378
# Epoch [    2/   10] | d_loss: 1.2270 | g_loss: 4.6764
# Epoch [    2/   10] | d_loss: 0.6748 | g_loss: 2.1201
# Epoch [    2/   10] | d_loss: 0.9579 | g_loss: 4.0348
# Epoch [    2/   10] | d_loss: 0.9690 | g_loss: 4.1511
# Epoch [    2/   10] | d_loss: 0.3047 | g_loss: 2.9393
# Epoch [    2/   10] | d_loss: 0.4740 | g_loss: 4.8994
# Epoch [    2/   10] | d_loss: 1.0856 | g_loss: 0.5017
# Epoch [    2/   10] | d_loss: 0.4330 | g_loss: 4.0814
# Epoch [    2/   10] | d_loss: 0.5340 | g_loss: 2.0513
# Epoch [    2/   10] | d_loss: 0.2790 | g_loss: 4.0969
# Epoch [    2/   10] | d_loss: 0.7357 | g_loss: 3.0415
# Epoch [    2/   10] | d_loss: 0.7115 | g_loss: 3.9036
# Epoch [    2/   10] | d_loss: 2.0173 | g_loss: 4.8497
# Epoch [    2/   10] | d_loss: 0.6365 | g_loss: 2.1643
# Epoch [    2/   10] | d_loss: 1.0020 | g_loss: 2.0412
# Epoch [    2/   10] | d_loss: 0.8192 | g_loss: 2.1933
# Epoch [    2/   10] | d_loss: 0.9457 | g_loss: 3.4554
# Epoch [    2/   10] | d_loss: 0.9636 | g_loss: 2.7469
# Epoch [    2/   10] | d_loss: 1.0847 | g_loss: 5.6337
# Epoch [    2/   10] | d_loss: 0.4606 | g_loss: 2.3408
# Epoch [    2/   10] | d_loss: 0.5457 | g_loss: 1.2590
# Epoch [    2/   10] | d_loss: 0.7054 | g_loss: 2.1938
# Epoch [    2/   10] | d_loss: 1.4275 | g_loss: 4.0036
# Epoch [    2/   10] | d_loss: 0.6243 | g_loss: 4.2064
# Epoch [    2/   10] | d_loss: 0.7910 | g_loss: 1.8302
# Epoch [    2/   10] | d_loss: 1.8284 | g_loss: 4.1135
# Epoch [    2/   10] | d_loss: 0.9998 | g_loss: 2.0837
# Epoch [    2/   10] | d_loss: 0.8765 | g_loss: 3.0788
# Epoch [    2/   10] | d_loss: 0.5510 | g_loss: 3.3257
# Epoch [    2/   10] | d_loss: 0.3703 | g_loss: 3.5169
# Epoch [    2/   10] | d_loss: 0.4374 | g_loss: 2.8107
# Epoch [    2/   10] | d_loss: 0.5105 | g_loss: 2.3206
# Epoch [    2/   10] | d_loss: 0.6973 | g_loss: 2.0952
# Epoch [    2/   10] | d_loss: 0.5868 | g_loss: 2.5272
# Epoch [    2/   10] | d_loss: 0.9409 | g_loss: 2.7950
# Epoch [    2/   10] | d_loss: 0.3455 | g_loss: 3.8200
# Epoch [    2/   10] | d_loss: 0.8504 | g_loss: 3.9764
# Epoch [    2/   10] | d_loss: 1.0776 | g_loss: 0.7785
# Epoch [    2/   10] | d_loss: 1.4155 | g_loss: 1.5695
# Epoch [    2/   10] | d_loss: 0.7861 | g_loss: 0.8975
# Epoch [    2/   10] | d_loss: 1.1101 | g_loss: 2.9541
# Epoch [    2/   10] | d_loss: 0.6270 | g_loss: 1.7010
# Epoch [    3/   10] | d_loss: 0.9783 | g_loss: 3.6252
# Epoch [    3/   10] | d_loss: 0.5130 | g_loss: 2.0242
# Epoch [    3/   10] | d_loss: 0.7917 | g_loss: 2.5639
# Epoch [    3/   10] | d_loss: 0.3627 | g_loss: 3.1009
# Epoch [    3/   10] | d_loss: 1.1177 | g_loss: 4.5586
# Epoch [    3/   10] | d_loss: 0.3747 | g_loss: 5.6569
# Epoch [    3/   10] | d_loss: 1.5442 | g_loss: 2.6371
# Epoch [    3/   10] | d_loss: 0.6572 | g_loss: 2.0639
# Epoch [    3/   10] | d_loss: 0.7569 | g_loss: 0.7456
# Epoch [    3/   10] | d_loss: 0.9674 | g_loss: 3.3274
# Epoch [    3/   10] | d_loss: 0.8972 | g_loss: 1.1934
# Epoch [    3/   10] | d_loss: 1.0905 | g_loss: 1.7233
# Epoch [    3/   10] | d_loss: 1.1252 | g_loss: 2.5208
# Epoch [    3/   10] | d_loss: 0.3867 | g_loss: 3.4464
# Epoch [    3/   10] | d_loss: 0.6193 | g_loss: 1.2571
# Epoch [    3/   10] | d_loss: 0.2879 | g_loss: 3.0676
# Epoch [    3/   10] | d_loss: 1.1574 | g_loss: 3.7253
# Epoch [    3/   10] | d_loss: 0.2598 | g_loss: 3.0072
# Epoch [    3/   10] | d_loss: 0.5559 | g_loss: 2.6333
# Epoch [    3/   10] | d_loss: 0.6615 | g_loss: 2.6832
# Epoch [    3/   10] | d_loss: 0.7159 | g_loss: 2.4837
# Epoch [    3/   10] | d_loss: 0.8326 | g_loss: 4.1372
# Epoch [    3/   10] | d_loss: 0.3788 | g_loss: 4.1499
# Epoch [    3/   10] | d_loss: 0.7423 | g_loss: 3.4608
# Epoch [    3/   10] | d_loss: 0.7701 | g_loss: 2.5815
# Epoch [    3/   10] | d_loss: 0.6425 | g_loss: 1.0833
# Epoch [    3/   10] | d_loss: 0.5267 | g_loss: 3.7083
# Epoch [    3/   10] | d_loss: 0.5818 | g_loss: 2.4236
# Epoch [    3/   10] | d_loss: 0.7593 | g_loss: 1.2155
# Epoch [    3/   10] | d_loss: 0.2688 | g_loss: 1.4357
# Epoch [    3/   10] | d_loss: 0.4161 | g_loss: 1.7075
# Epoch [    3/   10] | d_loss: 0.6182 | g_loss: 2.3495
# Epoch [    3/   10] | d_loss: 0.3698 | g_loss: 2.1784
# Epoch [    3/   10] | d_loss: 1.3304 | g_loss: 3.7315
# Epoch [    3/   10] | d_loss: 1.1261 | g_loss: 0.5430
# Epoch [    3/   10] | d_loss: 0.6001 | g_loss: 2.0788
# Epoch [    3/   10] | d_loss: 1.1854 | g_loss: 2.9887
# Epoch [    3/   10] | d_loss: 0.4455 | g_loss: 2.1439
# Epoch [    3/   10] | d_loss: 0.7235 | g_loss: 3.3254
# Epoch [    3/   10] | d_loss: 0.6997 | g_loss: 2.1413
# Epoch [    3/   10] | d_loss: 0.7454 | g_loss: 1.5978
# Epoch [    3/   10] | d_loss: 2.2103 | g_loss: 1.5340
# Epoch [    3/   10] | d_loss: 0.6031 | g_loss: 3.0059
# Epoch [    3/   10] | d_loss: 0.4510 | g_loss: 1.9983
# Epoch [    3/   10] | d_loss: 1.3060 | g_loss: 0.7626
# Epoch [    3/   10] | d_loss: 0.7568 | g_loss: 4.2737
# Epoch [    3/   10] | d_loss: 0.6095 | g_loss: 2.1288
# Epoch [    3/   10] | d_loss: 0.3932 | g_loss: 2.5813
# Epoch [    3/   10] | d_loss: 0.6160 | g_loss: 0.8731
# Epoch [    3/   10] | d_loss: 1.8878 | g_loss: 0.9179
# Epoch [    3/   10] | d_loss: 0.4286 | g_loss: 2.5036
# Epoch [    3/   10] | d_loss: 0.8213 | g_loss: 2.7221
# Epoch [    3/   10] | d_loss: 0.4986 | g_loss: 1.6014
# Epoch [    3/   10] | d_loss: 1.3582 | g_loss: 3.6653
# Epoch [    3/   10] | d_loss: 0.8429 | g_loss: 1.4540
# Epoch [    3/   10] | d_loss: 0.7928 | g_loss: 1.4967
# Epoch [    3/   10] | d_loss: 1.2159 | g_loss: 1.9761
# Epoch [    4/   10] | d_loss: 3.6625 | g_loss: 3.5421
# Epoch [    4/   10] | d_loss: 0.4454 | g_loss: 2.7776
# Epoch [    4/   10] | d_loss: 0.7860 | g_loss: 2.7185
# Epoch [    4/   10] | d_loss: 0.6512 | g_loss: 3.6996
# Epoch [    4/   10] | d_loss: 0.9911 | g_loss: 2.0864
# Epoch [    4/   10] | d_loss: 0.6839 | g_loss: 3.1474
# Epoch [    4/   10] | d_loss: 2.6949 | g_loss: 4.3326
# Epoch [    4/   10] | d_loss: 0.7225 | g_loss: 1.6190
# Epoch [    4/   10] | d_loss: 0.4774 | g_loss: 1.6790
# Epoch [    4/   10] | d_loss: 0.8990 | g_loss: 0.9776
# Epoch [    4/   10] | d_loss: 0.8743 | g_loss: 1.8371
# Epoch [    4/   10] | d_loss: 1.0755 | g_loss: 4.6485
# Epoch [    4/   10] | d_loss: 1.0829 | g_loss: 1.6754
# Epoch [    4/   10] | d_loss: 0.7267 | g_loss: 1.4476
# Epoch [    4/   10] | d_loss: 0.6876 | g_loss: 3.9837
# Epoch [    4/   10] | d_loss: 0.4867 | g_loss: 2.0358
# Epoch [    4/   10] | d_loss: 0.6617 | g_loss: 1.4813
# Epoch [    4/   10] | d_loss: 1.1345 | g_loss: 2.2007
# Epoch [    4/   10] | d_loss: 0.3993 | g_loss: 1.1279
# Epoch [    4/   10] | d_loss: 0.3719 | g_loss: 2.0486
# Epoch [    4/   10] | d_loss: 0.8276 | g_loss: 3.7166
# Epoch [    4/   10] | d_loss: 0.5241 | g_loss: 1.2036
# Epoch [    4/   10] | d_loss: 1.3164 | g_loss: 3.0841
# Epoch [    4/   10] | d_loss: 0.9544 | g_loss: 1.5372
# Epoch [    4/   10] | d_loss: 1.2798 | g_loss: 1.8487
# Epoch [    4/   10] | d_loss: 1.4738 | g_loss: 0.6783
# Epoch [    4/   10] | d_loss: 0.3042 | g_loss: 1.5753
# Epoch [    4/   10] | d_loss: 0.6283 | g_loss: 2.7350
# Epoch [    4/   10] | d_loss: 0.5888 | g_loss: 1.9488
# Epoch [    4/   10] | d_loss: 2.2170 | g_loss: 0.4361
# Epoch [    4/   10] | d_loss: 0.3801 | g_loss: 1.8918
# Epoch [    4/   10] | d_loss: 0.6777 | g_loss: 3.5797
# Epoch [    4/   10] | d_loss: 0.7255 | g_loss: 1.2126
# Epoch [    4/   10] | d_loss: 0.8609 | g_loss: 2.1208
# Epoch [    4/   10] | d_loss: 1.1376 | g_loss: 0.7030
# Epoch [    4/   10] | d_loss: 0.4277 | g_loss: 2.3694
# Epoch [    4/   10] | d_loss: 1.0680 | g_loss: 1.7740
# Epoch [    4/   10] | d_loss: 0.9312 | g_loss: 2.6358
# Epoch [    4/   10] | d_loss: 0.7689 | g_loss: 0.7682
# Epoch [    4/   10] | d_loss: 1.2128 | g_loss: 3.1602
# Epoch [    4/   10] | d_loss: 0.8536 | g_loss: 2.1404
# Epoch [    4/   10] | d_loss: 0.7776 | g_loss: 2.9228
# Epoch [    4/   10] | d_loss: 0.7663 | g_loss: 0.9305
# Epoch [    4/   10] | d_loss: 0.5911 | g_loss: 2.4081
# Epoch [    4/   10] | d_loss: 0.2648 | g_loss: 1.8164
# Epoch [    4/   10] | d_loss: 1.7972 | g_loss: 0.6165
# Epoch [    4/   10] | d_loss: 0.6113 | g_loss: 2.2313
# Epoch [    4/   10] | d_loss: 0.4256 | g_loss: 1.5121
# Epoch [    4/   10] | d_loss: 0.8392 | g_loss: 2.3259
# Epoch [    4/   10] | d_loss: 0.2308 | g_loss: 3.2940
# Epoch [    4/   10] | d_loss: 0.6526 | g_loss: 1.2404
# Epoch [    4/   10] | d_loss: 0.5013 | g_loss: 1.4429
# Epoch [    4/   10] | d_loss: 0.5925 | g_loss: 2.0440
# Epoch [    4/   10] | d_loss: 1.5726 | g_loss: 2.1552
# Epoch [    4/   10] | d_loss: 0.6679 | g_loss: 2.4376
# Epoch [    4/   10] | d_loss: 1.2989 | g_loss: 0.8539
# Epoch [    4/   10] | d_loss: 1.1571 | g_loss: 2.6676
# Epoch [    5/   10] | d_loss: 0.5511 | g_loss: 2.6759
# Epoch [    5/   10] | d_loss: 0.2822 | g_loss: 3.6727
# Epoch [    5/   10] | d_loss: 0.7572 | g_loss: 3.6798
# Epoch [    5/   10] | d_loss: 0.6523 | g_loss: 2.7246
# Epoch [    5/   10] | d_loss: 0.9600 | g_loss: 2.0813
# Epoch [    5/   10] | d_loss: 0.6749 | g_loss: 1.7865
# Epoch [    5/   10] | d_loss: 0.8573 | g_loss: 2.3335
# Epoch [    5/   10] | d_loss: 1.7582 | g_loss: 0.6458
# Epoch [    5/   10] | d_loss: 0.2867 | g_loss: 2.7228
# Epoch [    5/   10] | d_loss: 0.8039 | g_loss: 1.7159
# Epoch [    5/   10] | d_loss: 0.7105 | g_loss: 1.5730
# Epoch [    5/   10] | d_loss: 0.4149 | g_loss: 1.7526
# Epoch [    5/   10] | d_loss: 0.4045 | g_loss: 3.3142
# Epoch [    5/   10] | d_loss: 1.1621 | g_loss: 3.1617
# Epoch [    5/   10] | d_loss: 0.1940 | g_loss: 3.1379
# Epoch [    5/   10] | d_loss: 0.7149 | g_loss: 1.8590
# Epoch [    5/   10] | d_loss: 0.3676 | g_loss: 0.6496
# Epoch [    5/   10] | d_loss: 0.8414 | g_loss: 2.2739
# Epoch [    5/   10] | d_loss: 0.9095 | g_loss: 1.5168
# Epoch [    5/   10] | d_loss: 0.8520 | g_loss: 1.8254
# Epoch [    5/   10] | d_loss: 0.8224 | g_loss: 2.8195
# Epoch [    5/   10] | d_loss: 1.2144 | g_loss: 0.6895
# Epoch [    5/   10] | d_loss: 0.4381 | g_loss: 1.2208
# Epoch [    5/   10] | d_loss: 1.2464 | g_loss: 1.0268
# Epoch [    5/   10] | d_loss: 1.2078 | g_loss: 1.1906
# Epoch [    5/   10] | d_loss: 0.3734 | g_loss: 1.4523
# Epoch [    5/   10] | d_loss: 0.8740 | g_loss: 1.5448
# Epoch [    5/   10] | d_loss: 0.8440 | g_loss: 2.6903
# Epoch [    5/   10] | d_loss: 0.8018 | g_loss: 1.8542
# Epoch [    5/   10] | d_loss: 0.8868 | g_loss: 2.2459
# Epoch [    5/   10] | d_loss: 0.8915 | g_loss: 2.4095
# Epoch [    5/   10] | d_loss: 0.7562 | g_loss: 1.2592
# Epoch [    5/   10] | d_loss: 0.4948 | g_loss: 3.1738
# Epoch [    5/   10] | d_loss: 0.3041 | g_loss: 3.2643
# Epoch [    5/   10] | d_loss: 0.8096 | g_loss: 0.8621
# Epoch [    5/   10] | d_loss: 0.7392 | g_loss: 1.8440
# Epoch [    5/   10] | d_loss: 0.3893 | g_loss: 2.4782
# Epoch [    5/   10] | d_loss: 0.6835 | g_loss: 3.7127
# Epoch [    5/   10] | d_loss: 0.7813 | g_loss: 1.4222
# Epoch [    5/   10] | d_loss: 0.5586 | g_loss: 1.9775
# Epoch [    5/   10] | d_loss: 1.3495 | g_loss: 1.4178
# Epoch [    5/   10] | d_loss: 1.1709 | g_loss: 2.0610
# Epoch [    5/   10] | d_loss: 0.5582 | g_loss: 1.0674
# Epoch [    5/   10] | d_loss: 1.5012 | g_loss: 2.6003
# Epoch [    5/   10] | d_loss: 0.7635 | g_loss: 3.7309
# Epoch [    5/   10] | d_loss: 0.8962 | g_loss: 2.4035
# Epoch [    5/   10] | d_loss: 0.4880 | g_loss: 0.8663
# Epoch [    5/   10] | d_loss: 1.0824 | g_loss: 1.5167
# Epoch [    5/   10] | d_loss: 1.6637 | g_loss: 1.2382
# Epoch [    5/   10] | d_loss: 0.5452 | g_loss: 2.7330
# Epoch [    5/   10] | d_loss: 0.5237 | g_loss: 1.8510
# Epoch [    5/   10] | d_loss: 0.4332 | g_loss: 1.9639
# Epoch [    5/   10] | d_loss: 0.8777 | g_loss: 1.7004
# Epoch [    5/   10] | d_loss: 0.4540 | g_loss: 3.7266
# Epoch [    5/   10] | d_loss: 0.3557 | g_loss: 2.6603
# Epoch [    5/   10] | d_loss: 0.7193 | g_loss: 1.8533
# Epoch [    5/   10] | d_loss: 0.2912 | g_loss: 3.4703
# Epoch [    6/   10] | d_loss: 1.1769 | g_loss: 1.2290
# Epoch [    6/   10] | d_loss: 1.2840 | g_loss: 3.0501
# Epoch [    6/   10] | d_loss: 0.6483 | g_loss: 3.2952
# Epoch [    6/   10] | d_loss: 0.8576 | g_loss: 2.0314
# Epoch [    6/   10] | d_loss: 0.5385 | g_loss: 2.5962
# Epoch [    6/   10] | d_loss: 0.4368 | g_loss: 2.4241
# Epoch [    6/   10] | d_loss: 0.6532 | g_loss: 1.3691
# Epoch [    6/   10] | d_loss: 0.5448 | g_loss: 2.8812
# Epoch [    6/   10] | d_loss: 0.9569 | g_loss: 0.6199
# Epoch [    6/   10] | d_loss: 1.0570 | g_loss: 3.5853
# Epoch [    6/   10] | d_loss: 0.4031 | g_loss: 2.0398
# Epoch [    6/   10] | d_loss: 0.9765 | g_loss: 2.8408
# Epoch [    6/   10] | d_loss: 0.8129 | g_loss: 4.1884
# Epoch [    6/   10] | d_loss: 1.5537 | g_loss: 0.9304
# Epoch [    6/   10] | d_loss: 0.5746 | g_loss: 1.6083
# Epoch [    6/   10] | d_loss: 0.7841 | g_loss: 0.5038
# Epoch [    6/   10] | d_loss: 0.4946 | g_loss: 2.1320
# Epoch [    6/   10] | d_loss: 0.8009 | g_loss: 1.7425
# Epoch [    6/   10] | d_loss: 1.1573 | g_loss: 2.0162
# Epoch [    6/   10] | d_loss: 0.6315 | g_loss: 2.1281
# Epoch [    6/   10] | d_loss: 1.1407 | g_loss: 0.8438
# Epoch [    6/   10] | d_loss: 0.3849 | g_loss: 2.5372
# Epoch [    6/   10] | d_loss: 0.6259 | g_loss: 3.0535
# Epoch [    6/   10] | d_loss: 0.4399 | g_loss: 2.8172
# Epoch [    6/   10] | d_loss: 0.7867 | g_loss: 1.8217
# Epoch [    6/   10] | d_loss: 0.6037 | g_loss: 1.7211
# Epoch [    6/   10] | d_loss: 0.9702 | g_loss: 1.5153
# Epoch [    6/   10] | d_loss: 1.2663 | g_loss: 0.6802
# Epoch [    6/   10] | d_loss: 0.6740 | g_loss: 1.9282
# Epoch [    6/   10] | d_loss: 0.6428 | g_loss: 3.3596
# Epoch [    6/   10] | d_loss: 0.4114 | g_loss: 2.9938
# Epoch [    6/   10] | d_loss: 0.6664 | g_loss: 2.8674
# Epoch [    6/   10] | d_loss: 1.0401 | g_loss: 2.9443
# Epoch [    6/   10] | d_loss: 0.6084 | g_loss: 2.4768
# Epoch [    6/   10] | d_loss: 1.4282 | g_loss: 0.9712
# Epoch [    6/   10] | d_loss: 0.4871 | g_loss: 2.1262
# Epoch [    6/   10] | d_loss: 1.9334 | g_loss: 0.8792
# Epoch [    6/   10] | d_loss: 0.5219 | g_loss: 2.4168
# Epoch [    6/   10] | d_loss: 0.4340 | g_loss: 1.8407
# Epoch [    6/   10] | d_loss: 1.3710 | g_loss: 2.2676
# Epoch [    6/   10] | d_loss: 0.6740 | g_loss: 2.3510
# Epoch [    6/   10] | d_loss: 0.7837 | g_loss: 4.3467
# Epoch [    6/   10] | d_loss: 0.5135 | g_loss: 2.0754
# Epoch [    6/   10] | d_loss: 0.4589 | g_loss: 2.6830
# Epoch [    6/   10] | d_loss: 1.0451 | g_loss: 2.4304
# Epoch [    6/   10] | d_loss: 0.8930 | g_loss: 4.2070
# Epoch [    6/   10] | d_loss: 1.3561 | g_loss: 1.4797
# Epoch [    6/   10] | d_loss: 0.7163 | g_loss: 1.5146
# Epoch [    6/   10] | d_loss: 0.8874 | g_loss: 1.2679
# Epoch [    6/   10] | d_loss: 0.7488 | g_loss: 1.2101
# Epoch [    6/   10] | d_loss: 0.6947 | g_loss: 1.1597
# Epoch [    6/   10] | d_loss: 0.3130 | g_loss: 4.1872
# Epoch [    6/   10] | d_loss: 1.4726 | g_loss: 1.0395
# Epoch [    6/   10] | d_loss: 0.7212 | g_loss: 1.7372
# Epoch [    6/   10] | d_loss: 0.7725 | g_loss: 1.2123
# Epoch [    6/   10] | d_loss: 0.8859 | g_loss: 3.0058
# Epoch [    6/   10] | d_loss: 0.9005 | g_loss: 2.2519
# Epoch [    7/   10] | d_loss: 0.5906 | g_loss: 1.9680
# Epoch [    7/   10] | d_loss: 0.4751 | g_loss: 3.4281
# Epoch [    7/   10] | d_loss: 0.7116 | g_loss: 2.1160
# Epoch [    7/   10] | d_loss: 0.8637 | g_loss: 1.8129
# Epoch [    7/   10] | d_loss: 0.3393 | g_loss: 1.8296
# Epoch [    7/   10] | d_loss: 0.8499 | g_loss: 1.2933
# Epoch [    7/   10] | d_loss: 0.7147 | g_loss: 1.4696
# Epoch [    7/   10] | d_loss: 0.3214 | g_loss: 2.4427
# Epoch [    7/   10] | d_loss: 0.7215 | g_loss: 3.3991
# Epoch [    7/   10] | d_loss: 1.0012 | g_loss: 2.6093
# Epoch [    7/   10] | d_loss: 0.5624 | g_loss: 1.3754
# Epoch [    7/   10] | d_loss: 0.4504 | g_loss: 1.8684
# Epoch [    7/   10] | d_loss: 0.4556 | g_loss: 2.9681
# Epoch [    7/   10] | d_loss: 0.6025 | g_loss: 0.4774
# Epoch [    7/   10] | d_loss: 0.6966 | g_loss: 4.9021
# Epoch [    7/   10] | d_loss: 0.8542 | g_loss: 3.1193
# Epoch [    7/   10] | d_loss: 0.8372 | g_loss: 1.9642
# Epoch [    7/   10] | d_loss: 0.5026 | g_loss: 1.7751
# Epoch [    7/   10] | d_loss: 0.7686 | g_loss: 2.7564
# Epoch [    7/   10] | d_loss: 0.5214 | g_loss: 1.4623
# Epoch [    7/   10] | d_loss: 0.5905 | g_loss: 1.7915
# Epoch [    7/   10] | d_loss: 0.9751 | g_loss: 1.6519
# Epoch [    7/   10] | d_loss: 1.0586 | g_loss: 0.9938
# Epoch [    7/   10] | d_loss: 0.6942 | g_loss: 5.0915
# Epoch [    7/   10] | d_loss: 0.6751 | g_loss: 1.5245
# Epoch [    7/   10] | d_loss: 1.0778 | g_loss: 4.3317
# Epoch [    7/   10] | d_loss: 0.9685 | g_loss: 1.1289
# Epoch [    7/   10] | d_loss: 0.5794 | g_loss: 4.4888
# Epoch [    7/   10] | d_loss: 0.4531 | g_loss: 1.2902
# Epoch [    7/   10] | d_loss: 0.9935 | g_loss: 1.0281
# Epoch [    7/   10] | d_loss: 0.2779 | g_loss: 4.1087
# Epoch [    7/   10] | d_loss: 1.0474 | g_loss: 1.1467
# Epoch [    7/   10] | d_loss: 0.8325 | g_loss: 2.8759
# Epoch [    7/   10] | d_loss: 0.9168 | g_loss: 2.7228
# Epoch [    7/   10] | d_loss: 0.7009 | g_loss: 2.4065
# Epoch [    7/   10] | d_loss: 1.1942 | g_loss: 3.5551
# Epoch [    7/   10] | d_loss: 1.0501 | g_loss: 1.8748
# Epoch [    7/   10] | d_loss: 0.4082 | g_loss: 1.5534
# Epoch [    7/   10] | d_loss: 1.6235 | g_loss: 1.0572
# Epoch [    7/   10] | d_loss: 2.1435 | g_loss: 0.9988
# Epoch [    7/   10] | d_loss: 0.5644 | g_loss: 1.6091
# Epoch [    7/   10] | d_loss: 0.7926 | g_loss: 1.9852
# Epoch [    7/   10] | d_loss: 1.2750 | g_loss: 0.8998
# Epoch [    7/   10] | d_loss: 0.4820 | g_loss: 5.4136
# Epoch [    7/   10] | d_loss: 0.4055 | g_loss: 1.0008
# Epoch [    7/   10] | d_loss: 0.9137 | g_loss: 3.0669
# Epoch [    7/   10] | d_loss: 1.1302 | g_loss: 1.3865
# Epoch [    7/   10] | d_loss: 0.3497 | g_loss: 2.3517
# Epoch [    7/   10] | d_loss: 0.4787 | g_loss: 3.4328
# Epoch [    7/   10] | d_loss: 0.7109 | g_loss: 1.0695
# Epoch [    7/   10] | d_loss: 1.1622 | g_loss: 2.3974
# Epoch [    7/   10] | d_loss: 1.0187 | g_loss: 2.3384
# Epoch [    7/   10] | d_loss: 0.8481 | g_loss: 1.8974
# Epoch [    7/   10] | d_loss: 0.6311 | g_loss: 2.9013
# Epoch [    7/   10] | d_loss: 1.0132 | g_loss: 3.0949
# Epoch [    7/   10] | d_loss: 0.1573 | g_loss: 3.4246
# Epoch [    7/   10] | d_loss: 0.6794 | g_loss: 1.8715
# Epoch [    8/   10] | d_loss: 1.3396 | g_loss: 3.4303
# Epoch [    8/   10] | d_loss: 1.8426 | g_loss: 2.1455
# Epoch [    8/   10] | d_loss: 0.3570 | g_loss: 2.3239
# Epoch [    8/   10] | d_loss: 0.4507 | g_loss: 2.0684
# Epoch [    8/   10] | d_loss: 0.3494 | g_loss: 1.9204
# Epoch [    8/   10] | d_loss: 0.2921 | g_loss: 1.8202
# Epoch [    8/   10] | d_loss: 1.2235 | g_loss: 1.0514
# Epoch [    8/   10] | d_loss: 0.9987 | g_loss: 3.8510
# Epoch [    8/   10] | d_loss: 0.3452 | g_loss: 2.5002
# Epoch [    8/   10] | d_loss: 0.5147 | g_loss: 3.1427
# Epoch [    8/   10] | d_loss: 0.4596 | g_loss: 1.4116
# Epoch [    8/   10] | d_loss: 0.3685 | g_loss: 3.3837
# Epoch [    8/   10] | d_loss: 0.3899 | g_loss: 4.9167
# Epoch [    8/   10] | d_loss: 0.4035 | g_loss: 1.9184
# Epoch [    8/   10] | d_loss: 1.2763 | g_loss: 1.5518
# Epoch [    8/   10] | d_loss: 0.3853 | g_loss: 2.8939
# Epoch [    8/   10] | d_loss: 0.6123 | g_loss: 2.4390
# Epoch [    8/   10] | d_loss: 0.4995 | g_loss: 3.5710
# Epoch [    8/   10] | d_loss: 0.7125 | g_loss: 2.6969
# Epoch [    8/   10] | d_loss: 2.3623 | g_loss: 0.4118
# Epoch [    8/   10] | d_loss: 0.4340 | g_loss: 3.9544
# Epoch [    8/   10] | d_loss: 1.4229 | g_loss: 0.8628
# Epoch [    8/   10] | d_loss: 0.3835 | g_loss: 4.0024
# Epoch [    8/   10] | d_loss: 0.6606 | g_loss: 1.4944
# Epoch [    8/   10] | d_loss: 0.2056 | g_loss: 2.0691
# Epoch [    8/   10] | d_loss: 1.7792 | g_loss: 1.3713
# Epoch [    8/   10] | d_loss: 1.2864 | g_loss: 1.0451
# Epoch [    8/   10] | d_loss: 0.6760 | g_loss: 1.7896
# Epoch [    8/   10] | d_loss: 0.3354 | g_loss: 2.6724
# Epoch [    8/   10] | d_loss: 0.7871 | g_loss: 1.4037
# Epoch [    8/   10] | d_loss: 1.1162 | g_loss: 0.4738
# Epoch [    8/   10] | d_loss: 0.4802 | g_loss: 1.3399
# Epoch [    8/   10] | d_loss: 0.1820 | g_loss: 3.1713
# Epoch [    8/   10] | d_loss: 0.8267 | g_loss: 1.9261
# Epoch [    8/   10] | d_loss: 0.2640 | g_loss: 4.2865
# Epoch [    8/   10] | d_loss: 0.7528 | g_loss: 1.0413
# Epoch [    8/   10] | d_loss: 1.1542 | g_loss: 1.0070
# Epoch [    8/   10] | d_loss: 0.6819 | g_loss: 2.2877
# Epoch [    8/   10] | d_loss: 0.5448 | g_loss: 2.0690
# Epoch [    8/   10] | d_loss: 1.2439 | g_loss: 1.9045
# Epoch [    8/   10] | d_loss: 0.4432 | g_loss: 3.1287
# Epoch [    8/   10] | d_loss: 0.4925 | g_loss: 2.1481
# Epoch [    8/   10] | d_loss: 0.4902 | g_loss: 2.5311
# Epoch [    8/   10] | d_loss: 0.2296 | g_loss: 2.9105
# Epoch [    8/   10] | d_loss: 0.4031 | g_loss: 3.1860
# Epoch [    8/   10] | d_loss: 0.2751 | g_loss: 3.3816
# Epoch [    8/   10] | d_loss: 0.8923 | g_loss: 1.9735
# Epoch [    8/   10] | d_loss: 0.3367 | g_loss: 3.2358
# Epoch [    8/   10] | d_loss: 0.5757 | g_loss: 1.7262
# Epoch [    8/   10] | d_loss: 1.4203 | g_loss: 1.4478
# Epoch [    8/   10] | d_loss: 0.6587 | g_loss: 3.9858
# Epoch [    8/   10] | d_loss: 0.3433 | g_loss: 4.6991
# Epoch [    8/   10] | d_loss: 0.9109 | g_loss: 2.2227
# Epoch [    8/   10] | d_loss: 1.4997 | g_loss: 1.3748
# Epoch [    8/   10] | d_loss: 0.5394 | g_loss: 1.6536
# Epoch [    8/   10] | d_loss: 0.4359 | g_loss: 1.8977
# Epoch [    8/   10] | d_loss: 1.0339 | g_loss: 3.8252
# Epoch [    9/   10] | d_loss: 1.0493 | g_loss: 1.2856
# Epoch [    9/   10] | d_loss: 0.6115 | g_loss: 3.7201
# Epoch [    9/   10] | d_loss: 0.2609 | g_loss: 3.1324
# Epoch [    9/   10] | d_loss: 0.4488 | g_loss: 2.1590
# Epoch [    9/   10] | d_loss: 0.4281 | g_loss: 2.5430
# Epoch [    9/   10] | d_loss: 0.1428 | g_loss: 3.4244
# Epoch [    9/   10] | d_loss: 1.3190 | g_loss: 3.1750
# Epoch [    9/   10] | d_loss: 0.8790 | g_loss: 1.7629
# Epoch [    9/   10] | d_loss: 0.1205 | g_loss: 2.8093
# Epoch [    9/   10] | d_loss: 0.7205 | g_loss: 3.2392
# Epoch [    9/   10] | d_loss: 0.4526 | g_loss: 1.6784
# Epoch [    9/   10] | d_loss: 1.2973 | g_loss: 5.1109
# Epoch [    9/   10] | d_loss: 1.3599 | g_loss: 4.2064
# Epoch [    9/   10] | d_loss: 0.5655 | g_loss: 1.9710
# Epoch [    9/   10] | d_loss: 0.6142 | g_loss: 3.4779
# Epoch [    9/   10] | d_loss: 1.1761 | g_loss: 1.8011
# Epoch [    9/   10] | d_loss: 0.5349 | g_loss: 2.0027
# Epoch [    9/   10] | d_loss: 0.2803 | g_loss: 1.5829
# Epoch [    9/   10] | d_loss: 0.8468 | g_loss: 2.8891
# Epoch [    9/   10] | d_loss: 0.3777 | g_loss: 2.9775
# Epoch [    9/   10] | d_loss: 0.4564 | g_loss: 3.0523
# Epoch [    9/   10] | d_loss: 0.3002 | g_loss: 3.4642
# Epoch [    9/   10] | d_loss: 0.3262 | g_loss: 3.6231
# Epoch [    9/   10] | d_loss: 1.1844 | g_loss: 1.0818
# Epoch [    9/   10] | d_loss: 1.5294 | g_loss: 0.6397
# Epoch [    9/   10] | d_loss: 1.0678 | g_loss: 1.5876
# Epoch [    9/   10] | d_loss: 0.4647 | g_loss: 1.8202
# Epoch [    9/   10] | d_loss: 1.2827 | g_loss: 2.5185
# Epoch [    9/   10] | d_loss: 0.5801 | g_loss: 3.2232
# Epoch [    9/   10] | d_loss: 0.4429 | g_loss: 2.5319
# Epoch [    9/   10] | d_loss: 0.3188 | g_loss: 2.3096
# Epoch [    9/   10] | d_loss: 0.8470 | g_loss: 2.3773
# Epoch [    9/   10] | d_loss: 0.4716 | g_loss: 2.9994
# Epoch [    9/   10] | d_loss: 0.5442 | g_loss: 1.2742
# Epoch [    9/   10] | d_loss: 0.2289 | g_loss: 1.7138
# Epoch [    9/   10] | d_loss: 0.9093 | g_loss: 1.3689
# Epoch [    9/   10] | d_loss: 1.3245 | g_loss: 0.6603
# Epoch [    9/   10] | d_loss: 0.1991 | g_loss: 4.0329
# Epoch [    9/   10] | d_loss: 0.5901 | g_loss: 2.8199
# Epoch [    9/   10] | d_loss: 0.8077 | g_loss: 0.2541
# Epoch [    9/   10] | d_loss: 0.6683 | g_loss: 3.5664
# Epoch [    9/   10] | d_loss: 0.6586 | g_loss: 4.2329
# Epoch [    9/   10] | d_loss: 1.1617 | g_loss: 2.9071
# Epoch [    9/   10] | d_loss: 0.6665 | g_loss: 2.2753
# Epoch [    9/   10] | d_loss: 0.3829 | g_loss: 3.3465
# Epoch [    9/   10] | d_loss: 1.2867 | g_loss: 2.5165
# Epoch [    9/   10] | d_loss: 0.9144 | g_loss: 3.1939
# Epoch [    9/   10] | d_loss: 0.2100 | g_loss: 4.4170
# Epoch [    9/   10] | d_loss: 0.8547 | g_loss: 2.0830
# Epoch [    9/   10] | d_loss: 0.5669 | g_loss: 2.6260
# Epoch [    9/   10] | d_loss: 1.5480 | g_loss: 3.1536
# Epoch [    9/   10] | d_loss: 1.3750 | g_loss: 2.5624
# Epoch [    9/   10] | d_loss: 0.2002 | g_loss: 2.2204
# Epoch [    9/   10] | d_loss: 0.5611 | g_loss: 3.1599
# Epoch [    9/   10] | d_loss: 0.3483 | g_loss: 3.4386
# Epoch [    9/   10] | d_loss: 1.0466 | g_loss: 0.8665
# Epoch [    9/   10] | d_loss: 0.5498 | g_loss: 4.8955
# Epoch [   10/   10] | d_loss: 0.4777 | g_loss: 3.5491
# Epoch [   10/   10] | d_loss: 0.6485 | g_loss: 4.3389
# Epoch [   10/   10] | d_loss: 0.7808 | g_loss: 3.4582
# Epoch [   10/   10] | d_loss: 0.8097 | g_loss: 4.2325
# Epoch [   10/   10] | d_loss: 0.6625 | g_loss: 2.3278
# Epoch [   10/   10] | d_loss: 0.4204 | g_loss: 4.3108
# Epoch [   10/   10] | d_loss: 0.2319 | g_loss: 3.1103
# Epoch [   10/   10] | d_loss: 0.8263 | g_loss: 1.6341
# Epoch [   10/   10] | d_loss: 0.7228 | g_loss: 2.0478
# Epoch [   10/   10] | d_loss: 0.9823 | g_loss: 2.2411
# Epoch [   10/   10] | d_loss: 0.3771 | g_loss: 3.3577
# Epoch [   10/   10] | d_loss: 0.4590 | g_loss: 1.8156
# Epoch [   10/   10] | d_loss: 0.8441 | g_loss: 3.3172
# Epoch [   10/   10] | d_loss: 0.6565 | g_loss: 3.3451
# Epoch [   10/   10] | d_loss: 0.1700 | g_loss: 4.2026
# Epoch [   10/   10] | d_loss: 0.5323 | g_loss: 2.1909
# Epoch [   10/   10] | d_loss: 1.2611 | g_loss: 1.9452
# Epoch [   10/   10] | d_loss: 1.1064 | g_loss: 2.4290
# Epoch [   10/   10] | d_loss: 0.6434 | g_loss: 2.4031
# Epoch [   10/   10] | d_loss: 0.2422 | g_loss: 4.6677
# Epoch [   10/   10] | d_loss: 1.4489 | g_loss: 4.9463
# Epoch [   10/   10] | d_loss: 0.4925 | g_loss: 2.8119
# Epoch [   10/   10] | d_loss: 0.8919 | g_loss: 2.0535
# Epoch [   10/   10] | d_loss: 0.2781 | g_loss: 3.1025
# Epoch [   10/   10] | d_loss: 0.5563 | g_loss: 1.7309
# Epoch [   10/   10] | d_loss: 0.2897 | g_loss: 5.7505
# Epoch [   10/   10] | d_loss: 0.6244 | g_loss: 2.7431
# Epoch [   10/   10] | d_loss: 0.9389 | g_loss: 2.7058
# Epoch [   10/   10] | d_loss: 0.8674 | g_loss: 2.3276
# Epoch [   10/   10] | d_loss: 0.8584 | g_loss: 3.3634
# Epoch [   10/   10] | d_loss: 0.3035 | g_loss: 4.0641
# Epoch [   10/   10] | d_loss: 0.5060 | g_loss: 5.2442
# Epoch [   10/   10] | d_loss: 0.7114 | g_loss: 4.3397
# Epoch [   10/   10] | d_loss: 0.3749 | g_loss: 3.2091
# Epoch [   10/   10] | d_loss: 0.6977 | g_loss: 3.2659
# Epoch [   10/   10] | d_loss: 0.2204 | g_loss: 4.3199
# Epoch [   10/   10] | d_loss: 0.9900 | g_loss: 3.0495
# Epoch [   10/   10] | d_loss: 0.2933 | g_loss: 4.2700
# Epoch [   10/   10] | d_loss: 0.8235 | g_loss: 1.2734
# Epoch [   10/   10] | d_loss: 0.6091 | g_loss: 3.1023
# Epoch [   10/   10] | d_loss: 0.1244 | g_loss: 3.4061
# Epoch [   10/   10] | d_loss: 0.3022 | g_loss: 2.6214
# Epoch [   10/   10] | d_loss: 0.3621 | g_loss: 3.4239
# Epoch [   10/   10] | d_loss: 0.6270 | g_loss: 1.1636
# Epoch [   10/   10] | d_loss: 0.7315 | g_loss: 3.8772
# Epoch [   10/   10] | d_loss: 0.5299 | g_loss: 1.6130
# Epoch [   10/   10] | d_loss: 0.3637 | g_loss: 3.3007
# Epoch [   10/   10] | d_loss: 0.4717 | g_loss: 3.8615
# Epoch [   10/   10] | d_loss: 0.6882 | g_loss: 2.1370
# Epoch [   10/   10] | d_loss: 0.6024 | g_loss: 4.3627
# Epoch [   10/   10] | d_loss: 1.1344 | g_loss: 3.2571
# Epoch [   10/   10] | d_loss: 0.4202 | g_loss: 1.7271
# Epoch [   10/   10] | d_loss: 0.3096 | g_loss: 1.0854
# Epoch [   10/   10] | d_loss: 0.6360 | g_loss: 2.0831
# Epoch [   10/   10] | d_loss: 0.3675 | g_loss: 1.9002
# Epoch [   10/   10] | d_loss: 0.4919 | g_loss: 2.5813
# Epoch [   10/   10] | d_loss: 0.4658 | g_loss: 1.5570

# %% [markdown]
# ## Training loss
#
# Plot the training losses for the generator and discriminator, recorded after each epoch.

# %%
fig, ax = plt.subplots()
losses = np.array(losses)
plt.plot(losses.T[0], label='Discriminator', alpha=0.5)
plt.plot(losses.T[1], label='Generator', alpha=0.5)
plt.title("Training Losses")
plt.legend()

# %% [markdown]
# ## Generator samples from training
#
# View samples of images from the generator, and answer a question about the strengths and weaknesses of your trained models.

# %%
# helper function for viewing a list of passed in sample images
def view_samples(epoch, samples):
    fig, axes = plt.subplots(figsize=(16,4), nrows=2, ncols=8, sharey=True, sharex=True)
    for ax, img in zip(axes.flatten(), samples[epoch]):
        img = img.detach().cpu().numpy()
        img = np.transpose(img, (1, 2, 0))
        img = ((img + 1)*255 / (2)).astype(np.uint8)
        ax.xaxis.set_visible(False)
        ax.yaxis.set_visible(False)
        im = ax.imshow(img.reshape((32,32,3)))

# %%
# Load samples from generator, taken while training
with open('train_samples.pkl', 'rb') as f:
    samples = pkl.load(f)

# %%
_ = view_samples(-1, samples)

# %% [markdown]
# ### Question: What do you notice about your generated samples and how might you improve this model?
# When you answer this question, consider the following factors:
# * The dataset is biased; it is made of "celebrity" faces that are mostly white
# * Model size; larger models have the opportunity to learn more features in a data feature space
# * Optimization strategy; optimizers and number of epochs affect your final result

# %% [markdown]
# **Answer:** (Write your answer in this cell)
# - We can reduce bias by adding people with different kinds of skin tone
# - It's obvious that larger models will have more probability to learn more features
# - But these models also takes more amount of time for execution
# - So we should consider the perfect balance between both
# - I have used Adam Optimizer, these optimizers performs well in GAN's really well
# - We could also use SGD

# %% [markdown]
# ### Submitting This Project
# When submitting this project, make sure to run all the cells before saving the notebook. Save the notebook file as "dlnd_face_generation.ipynb" and save it as a HTML file under "File" -> "Download as". Include the "problem_unittests.py" files in your submission.
